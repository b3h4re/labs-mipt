# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# напряжение и ток из-за смещения контактов
V_0 = np.float64('0.287')       # V
sigma_V_0 = np.float64('0.003') # V

I_0 = np.float64('317.5')       # mA
sigma_I_0 = np.float64('0.5')   # mA
