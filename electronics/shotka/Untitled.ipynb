# %%
import numpy as np
import matplotlib as plt
import os

# %%
def get_extension(filepath):
    return filepath.split(".")[-1]

# %%
BASE_DIR = os.path.abspath(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, 'gr4_306_14_02')

dirs = []
headers = []

for filepath in os.listdir(DATA_DIR):
    if os.path.isfile(os.path.join(DATA_DIR, filepath)):
        headers.append(filepath)
    else:
        dirs.append(filepath)

print(dirs, headers)
# Out:
# ['1-fusedAl-fusedAl-min_distance', '1-Al-Al', '1-fusedAl-fusedAl-max_distance', '1-fusedAu-fusedAl', '1-Al', '1-Au', '1-Au-melted', '1-Al-fusedAl', '1-Al-melted'] ['1-Al.header', '1-Al-fusedAl.header', '1-Au-melted.header', '1-fusedAl-fusedAl-min_distance.header', '1-fusedAl-fusedAl-max_distance.header', '1-fusedAu-fusedAl.header', '1-Al-melted.header', '1-Au.header', '1-Al-Al.header']

# %%
def read_data(data_dir):
    header = data_dir + ".header"
    file = open(os.path.join(DATA_DIR, data_dir + ".header"))
    text = file.readlines()
    file.close()
    return text

# %%
read_data(dirs[0])
# Out:
# ['B1500A file ver 2.0\n',
#  '\n',
#  '              Sample              Contact\n',
#  '       gr4_306_14_02 1-fusedAl-fusedAl-min_distance\n',
#  '______________________________________________________\n',
#  '\n',
#  '  Measurement Number     Measurement type\n',
#  '                   1                DC IV\n',
#  '\n',
#  '      Measurement ID             SeriesID\n',
#  '       739662.671741                    0\n',
#  '\n',
#  '              File:  \\1-fusedAl-fusedAl-min_distance\\1.data\n',
#  '\n',
#  '______________________________________________________\n',
#  '\n',
#  '  Measurement Number     Measurement type\n',
#  '                   2           CVSweepNew\n',
#  '\n',
#  '      Measurement ID             SeriesID\n',
#  '       739662.673107                    0\n',
#  '\n',
#  '              File:  \\1-fusedAl-fusedAl-min_distance\\2.data\n',
#  '\n',
#  '______________________________________________________\n',
#  '\n']
